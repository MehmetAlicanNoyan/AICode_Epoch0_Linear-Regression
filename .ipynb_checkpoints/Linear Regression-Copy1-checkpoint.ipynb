# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 5 # number of examples
n = 1 # number of features

# %%
X = np.random.uniform(size=(m,n))
X
# Out:
# array([[0.41167748],
#        [0.22399758],
#        [0.14487854],
#        [0.05619758],
#        [0.47414502]])

# %%
X = np.concatenate((np.ones((m,1)), X), axis = 1)
X
# Out:
# array([[1.        , 0.41167748],
#        [1.        , 0.22399758],
#        [1.        , 0.14487854],
#        [1.        , 0.05619758],
#        [1.        , 0.47414502]])

# %%
theta_true = np.random.uniform(size=(n+1,1))
theta_true
# Out:
# array([[0.11959078],
#        [0.09691387]])

# %%
y = np.dot(X,theta_true)
y
# Out:
# array([[0.15948804],
#        [0.14129925],
#        [0.13363152],
#        [0.12503711],
#        [0.16554201]])

# %%
plt.scatter(X[:,1],y)

# %%
def plotter(X, y, theta):
    plt.scatter(X[:,1],y)

    linex = np.linspace(X[:,1].min(),X[:,1].max())
    liney = theta[0] + theta[1]*linex
    plt.plot(linex,liney)

# %%
plotter(X, y, theta_true)

# %%
theta = np.random.uniform(size=(n+1,1))
theta
# Out:
# array([[0.09342628],
#        [0.06635953]])

# %%
plotter(X, y, theta)

# %%
def cost_function(X, y, theta):
    y_pred = np.dot(X, theta)
    cost = (0.5*m)*np.sum((y - y_pred)**2)
    return cost

# %%
cost_function(X, y, theta)
# Out:
# 0.014890878164479024

# %%
cost_function(X, y, theta_true)
# Out:
# 0.0

# %%
def GD_one_step(X, y, theta, lr):
    y_pred = np.dot(X, theta)
    theta_new = np.zeros(theta.shape)
    for i in range(n+1):
        theta_new[i] = theta[i] - (lr/m)*np.sum((y_pred-y)*X[:,i].reshape(-1,1))
    return theta_new

# %%
print('theta: ', theta.T)
print('theta_true: ', theta_true.T)
# Out:
# theta:  [[0.09342628 0.06635953]]
# theta_true:  [[0.11959078 0.09691387]]

# %%
theta=GD_one_step(X, y, theta, lr=0.01)
theta
# Out:
# array([[0.09376804],
#        [0.06645676]])

# %%
def GD(X, y, lr, epoch):
    theta = np.random.uniform(size=(n+1,1))
    for i in range(epoch):
        theta=GD_one_step(X, y, theta, lr)
    return theta

# %%
theta = GD(X, y, lr=0.01, epoch=10000)

# %%
plotter(X, y, theta)

# %%
def plotter_multiple(X, y, thetas):
    plt.scatter(X[:,1],y)
    
    for theta in thetas:
        linex = np.linspace(X[:,1].min(),X[:,1].max())
        liney = theta[0] + theta[1]*linex
        plt.plot(linex,liney)

# %%
plotter_multiple(X, y, [theta, theta_true])

# %%
# We need a way to monitor training
def GD_memory(X, y, lr, epoch):
    memory = []
    theta = np.random.uniform(size=(n+1,1))
    for i in range(epoch):
        memory.append(theta)
        theta=GD_one_step(X, y, theta, lr)        
    return theta, memory

# %%
theta, memory = GD_memory(X, y, lr=0.01, epoch=500)

# %%
# dont plot everything but sample each 10, or maybe logaritmically
plotter_multiple(X, y, memory)

# %%
# the above way is very good BUT what happens when we have more than one feature?
# we should plot loss i.e. learning curve

# %%
def plot_loss(X, y, memory):
    losses = []
    for theta in memory:
        loss = cost_function(X, y, theta)
        losses.append(loss)
    plt.plot(losses)
    plt.ylabel('loss')
    plt.xlabel('number of epochs')

# %%
plot_loss(X, y, memory)

# %%
theta, memory = GD_memory(X, y, lr=0.01, epoch=1000)
plot_loss(X, y, memory)

# %%
# so far we have only fit ideal datapoints
# so let's get real
y_real = y * np.random.uniform(0.97,1.03,m).reshape(-1,1)

# %%
plotter(X, y_real, theta_true)

# %%
theta, memory = GD_memory(X, y_real, lr=0.01, epoch=10000)

# %%
plot_loss(X, y_real, memory)

# %%
plotter_multiple(X, y_real, [theta, theta_true])

# %%
theta, memory = GD_memory(X, y_real, lr=0.1, epoch=1000)
plot_loss(X, y_real, memory)

# %%
m = 5 # number of examples
n = 2 # number of features

# %%
X = np.random.uniform(size=(m,n))
X
# Out:
# array([[0.87592255, 0.58643051],
#        [0.24342903, 0.21068973],
#        [0.10766042, 0.60189445],
#        [0.62051123, 0.1889443 ],
#        [0.58736906, 0.87556362]])

# %%
X = np.concatenate((np.ones((m,1)), X), axis = 1)
X
# Out:
# array([[1.        , 0.87592255, 0.58643051],
#        [1.        , 0.24342903, 0.21068973],
#        [1.        , 0.10766042, 0.60189445],
#        [1.        , 0.62051123, 0.1889443 ],
#        [1.        , 0.58736906, 0.87556362]])

# %%
theta_true = np.random.uniform(size=(n+1,1))
theta_true
# Out:
# array([[0.55905216],
#        [0.0609411 ],
#        [0.89622208]])

# %%
y = np.dot(X, theta_true)

# %%
theta, memory = GD_memory(X, y, lr=0.01, epoch=5000)
plot_loss(X, y, memory)

# %%
print('theta: ', theta.T)
print('theta_true: ', theta_true.T)
# Out:
# theta:  [[0.56061828 0.06423887 0.88993256]]
# theta_true:  [[0.55905216 0.0609411  0.89622208]]

# %%
np.dot(X, theta)[0], y[0]
# Out:
# (array([1.13877016]), array([1.13800382]))
